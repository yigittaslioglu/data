# %% [markdown]
# # demo nba verileri 20.13

# %%
#1- ilk on kaydı getiri
#2- toplam kaç kayıt vardır
#3- tüm oyunvuların toplam maaş ortalaması nedir
#4- en yüksek maaş ne kadardır
#5- en yüksek maaşı alan oyuncu kimdir
#6- yaşı 20-25 arasında olan oyuncunun oynadığı ismi ve takımı azalan sırayla hangisidir
#7- Taurean Green isimli oyuncunun oynadığı takım hangisidir
#8- takımlara göre oyuncuları ortalama maaş bilgisi nedir
#9- kaç farklı takım mevcuttur
#10- he rtakımda kaç oyuncu oynamaktadır
#11- ismi içinde "and geçen kayıtları bulunuz."

# %%
import pandas as pd

# %%
#1-

df = pd.read_csv("all_seasons.csv")

df.head(10)
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 1           1  Dwayne Schintzius               LAC  28.0         215.90
# 2           2       Earl Cureton               TOR  39.0         205.74
# 3           3        Ed O'Bannon               DAL  24.0         203.20
# 4           4        Ed Pinckney               MIA  34.0         205.74
# 5           5      Eddie Johnson               HOU  38.0         200.66
# 6           6        Eddie Jones               LAL  25.0         198.12
# 7           7     Elden Campbell               LAL  28.0         213.36
# 8           8  Eldridge Recasner               ATL  29.0         193.04
# 9           9       Elliot Perry               MIL  28.0         182.88
#
#    player_weight                      college country draft_year draft_round  \
# 0      99.790240  Southeastern Oklahoma State     USA       1986           2
# ...

# %%
#2-

len(df.index) #kaç satır var
# Out:
# 12305

# %%
#3-
result = df["player_weight"].mean() #oyuncuların ortalama kilosu
result
# Out:
# 100.36992618155222

# %%
#4-
df["player_weight"].max() #en ağır oyuncu
# Out:
# 163.29312

# %%
#5-

result = df[df["player_weight"] == df["player_weight"].max()]["player_name"].iloc[0] # içine varip eşit eşit mi diye sorarsam o kolonun bağlı olduğu kolon gelir
result # kolon gelirse tüm bilgileri gelir ve iloc dersem de sadece ismi gelir, namei tek yazarsam indexi de geliyor
# Out:
# 'Sim Bhullar'

# %%
#6- 

result = df[(df["player_height"] > 180) & (df["player_height"] < 185.2)][["player_name","college","age"]].sort_values("age", ascending = False)
result #and yazarsam hat averdi ancak & yazdığımda çalıştı
# Out:
#              player_name      college   age
# 3394       Avery Johnson     Southern  39.0
# 2743       Avery Johnson     Southern  38.0
# 4925      Darrick Martin         UCLA  37.0
# 2520       Avery Johnson     Southern  37.0
# 11967         Chris Paul  Wake Forest  37.0
# ...                  ...          ...   ...
# 5292       Taurean Green      Florida  21.0
# 4218   Sebastian Telfair         None  21.0
# 4708          Kyle Lowry    Villanova  21.0
# 4170          Chris Paul  Wake Forest  21.0
# 3623   Sebastian Telfair         None  20.0
#
# [397 rows x 3 columns]

# %%
#7-

result = df[(df["player_name"] == "Taurean Green")][["college","player_name"]]
result
# Out:
#       college    player_name
# 5292  Florida  Taurean Green

# %%
#8- 
result = df.groupby("college").mean()["player_height"].sort_values(ascending = False)
result
# Out:
# C:\Users\PC-1\AppData\Local\Temp\ipykernel_14104\1502411590.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result = df.groupby("college").mean()["player_height"].sort_values(ascending = False)
# college
# UCF                         228.60
# Central State (OH)          223.52
# Marist                      223.52
# Yonsei (KOR)                220.98
# Barton Community College    220.98
#                              ...
# California-Irvine           180.34
# Portland                    180.34
# LSU                         177.80
# Campbell University         175.26
# Brigham Young-Hawaii        175.26
# Name: player_height, Length: 347, dtype: float64

# %%
#9-
result = len(df.groupby("college"))

result = df["college"].nunique() #hepsi aynı sonucu veriyor

result = len(df["college"].unique())

result
# Out:
# 347

# %%
#10-

result = df["college"].value_counts()
result #her takımda kaç oyuncu olduğu bilgisi
# Out:
# None                              1789
# Kentucky                           420
# Duke                               384
# North Carolina                     344
# UCLA                               307
#                                   ...
# George Mason                         1
# University of Colorado Boulder       1
# Illinois State                       1
# Augustana (SD)                       1
# UNC                                  1
# Name: college, Length: 347, dtype: int64

# %%
#11-

result = df[df["player_name"].str.contains("and")]
result #str metodlarından contains fonksiyonu ile isim kolonu içinde and kelimelerini arayabiliyorum
# Out:
#        Unnamed: 0               player_name team_abbreviation   age  \
# 22             22          Erick Strickland               DAL  23.0
# 145           145     Aleksandar Djordjevic               POR  29.0
# 171           171            Cory Alexander               SAS  24.0
# 237           237          Shandon Anderson               UTA  23.0
# 250           250        Randolph Childress               DET  24.0
# ...           ...                       ...               ...   ...
# 12033       12033   Shai Gilgeous-Alexander               OKC  23.0
# 12174       12174           Leandro Bolmaro               MIN  21.0
# 12179       12179             Landry Shamet               PHX  25.0
# 12227       12227             Julius Randle               NYK  27.0
# 12256       12256  Nickeil Alexander-Walker               UTA  23.0
#
#        player_height  player_weight        college    country draft_year  \
# 22            190.50      95.254320       Nebraska        USA  Undrafted
# ...

# %%
def str(name):
    if "and" in name.lower():
        return True
    return False

result = df[df["player_name"].apply(str)].head()

print(result) #bu şekilde de yazılablir 11in cevabı
# Out:
#      Unnamed: 0            player_name team_abbreviation   age  player_height  \
# 22           22       Erick Strickland               DAL  23.0         190.50
# 97           97          Greg Anderson               SAS  33.0         208.28
# 145         145  Aleksandar Djordjevic               POR  29.0         187.96
# 151         151        Andrew DeClercq               GSW  24.0         208.28
# 152         152            Andrew Lang               MIL  31.0         210.82
#
#      player_weight   college country draft_year draft_round  ...   pts  reb  \
# 22       95.254320  Nebraska     USA  Undrafted   Undrafted  ...  10.6  3.2
# 97      113.398000   Houston     USA       1987           1  ...   3.9  5.5
# 145      89.811216      None     USA  Undrafted   Undrafted  ...   3.1  0.6
# 151     104.326160   Florida     USA       1995           2  ...   5.3  4.2
# 152     124.737800  Arkansas     USA       1988           2  ...   5.3  5.3
#
# ...

# %% [markdown]
# # 20.14 youtube istatistik verilerinin analizi

# %%
import pandas as pd

# %%
#1-ilk on kaydı getirin
#2-ikinci 5 kaydı getirin
#3- datasette bulunan kolon isimlerini ve sayısını bulun
#4- aşağıda bulunan bazı kolonları silin 
#5- beğenme ve beğenmeme sayılarının ortalamasını yazdırın
#6- ilk 50 videonun like ve dislike kolonlarını getirin
#7- en çok görüntülenen video hangisi
#8- en düşük görüntülenme alan video hangisi
#9- en fazla görüntülenen video hangisi
#10- kategoriye göre beğeni ortalamalrını sıralı şekilde getirin
#11- kategoriye göre yorum sıralmalarını yukarıdan aşağıya doğru sıralı şekilde getirin
#12- her kategoride kaç video var
#13- her videoun title uzunluğu bilgisini yeni bir kolonda gösterin
#14- her video için kullanılan tag sayısını yeni bir kolonda gösterin
#15- en popüler videoalrı listeleyiniz (like/dislike oranına göre)

# %%
df = pd.read_csv("GBvideos.csv")
df
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
#1-
df.head(10)
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
# 5  AumaWl0TNBo      17.14.11
# 6  2Vv-BfVoq4g      17.14.11
# 7  -N5eucPMTTc      17.14.11
# 8  LMCuKltaY3M      17.14.11
# 9  9t9u_yPEidY      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
# 5                       How My Relationship Started!
# 6        Ed Sheeran - Perfect (Official Music Video)
# 7                      CHRISTMAS HAS GONE TO MY HEAD
# 8   Elbow - Golden Slumbers (John Lewis Advert 2017)
# 9  Jennifer Lopez - Amor, Amor, Amor (Official Vi...
#
# ...

# %%
#2-
df[5:20].head(5) #ya da direkt 5:10 yazarsam ikinci 5lik kaydı almış olurum
# Out:
#       video_id trending_date  \
# 5  AumaWl0TNBo      17.14.11
# 6  2Vv-BfVoq4g      17.14.11
# 7  -N5eucPMTTc      17.14.11
# 8  LMCuKltaY3M      17.14.11
# 9  9t9u_yPEidY      17.14.11
#
#                                                title       channel_title  \
# 5                       How My Relationship Started!  PointlessBlogVlogs
# 6        Ed Sheeran - Perfect (Official Music Video)          Ed Sheeran
# 7                      CHRISTMAS HAS GONE TO MY HEAD          MoreZoella
# 8   Elbow - Golden Slumbers (John Lewis Advert 2017)           ElbowVEVO
# 9  Jennifer Lopez - Amor, Amor, Amor (Official Vi...   JenniferLopezVEVO
#
#    category_id              publish_time  \
# 5           24  2017-11-11T17:00:00.000Z
# 6           10  2017-11-09T11:04:14.000Z
# 7           22  2017-11-10T19:19:43.000Z
# 8           10  2017-11-10T08:00:01.000Z
# 9           10  2017-11-10T15:00:00.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
#3-
df.columns
len(df.columns)
# Out:
# 16

# %%
#4-
df = df.drop(["thumbnail_link","comments_disabled","ratings_disabled","video_error_or_removed","description","trending_date"],axis = 1)
df
# Out:
#           video_id                                              title  \
# 0      Jw1Y-zhQURU      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1      3s1rvMFUweQ          Taylor Swift: …Ready for It? (Live) - SNL
# 2      n1WpP7iowLc         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      PUTEiSjKwJU  Goals from Salford City vs Class of 92 and Fri...
# 4      rHwDegptbI4  Dashcam captures truck's near miss with child ...
# ...            ...                                                ...
# 38911  l884wKofd54  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  IP8k2xkhOdI  Jacob Sartorius - Up With It (Official Music V...
# 38913  Il-an3K9pjg                 Anne-Marie - 2002 [Official Video]
# 38914  -DRsfNObKIQ  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  4YFo4bdMO8Q  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                     channel_title  category_id              publish_time  \
# ...

# %%
#5-
result = df["likes"].mean() 
result = df["dislikes"].mean()
result
# Out:
# 7612.559975331483

# %%
#6- 
result = df.head(50)[["title","likes","dislikes"]]
result
# Out:
#                                                 title    likes  dislikes
# 0       John Lewis Christmas Ad 2017 - #MozTheMonster    55681     10247
# 1           Taylor Swift: …Ready for It? (Live) - SNL    25561      2294
# 2          Eminem - Walk On Water (Audio) ft. Beyoncé   787420     43420
# 3   Goals from Salford City vs Class of 92 and Fri...      193        12
# 4   Dashcam captures truck's near miss with child ...       30         2
# 5                        How My Relationship Started!    52708      1431
# 6         Ed Sheeran - Perfect (Official Music Video)  1634124     21082
# 7                       CHRISTMAS HAS GONE TO MY HEAD    57309       749
# 8    Elbow - Golden Slumbers (John Lewis Advert 2017)     2163       147
# 9   Jennifer Lopez - Amor, Amor, Amor (Official Vi...   190084     15015
# 10        CAN BABIES DO GYMNASTICS?  **World Record**     9591       266
# 11  TV Reporter Interviews Alleged Bank Robber, Th...     1746       125
# ...

# %%
#7-
result = df[df["views"].max() == df["views"]][["title"]].iloc[0]
result
# Out:
# title    Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...
# Name: 28412, dtype: object

# %%
#8-
result = df[df["views"].min() == df["views"]]["title"].iloc[0]
result
# Out:
# 'Mountain Bikers Worried About Military Land Being Fenced Off'

# %%
#9-
result = df.sort_values("views",ascending=False)[["title","views"]].head(10)
result
# Out:
#                                                    title      views
# 28412  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912
# 28212  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  413586699
# 28008  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  402650804
# 27811  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  392036878
# 27615  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  382401497
# 27424  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  372399338
# 27241  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  362111555
# 27052  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  349987176
# 26861  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  339629489
# 34460  Te Bote Remix - Casper, Nio García, Darell, Ni...  337621571

# %%
#10-
result = df.groupby("category_id").mean().sort_values("likes",ascending = False)["likes"]
result
# Out:
# C:\Users\PC-1\AppData\Local\Temp\ipykernel_14104\3204617002.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result = df.groupby("category_id").mean().sort_values("likes",ascending = False)["likes"]
# category_id
# 10    272138.508943
# 29    271695.733333
# 24     81572.362012
# 23     78431.168490
# 28     61531.127413
# 1      57205.523089
# 22     46273.495899
# 43     41836.900000
# 17     39270.313057
# 20     39220.127517
# 27     38440.687090
# 15     28629.913858
# 26     26639.183091
# 25     25021.685714
# 2      24608.506944
# 19      9674.447917
# Name: likes, dtype: float64

# %%
#11-
result = df.groupby("category_id").sum().sort_values("comment_count",ascending=False)["comment_count"]
result
# Out:
# C:\Users\PC-1\AppData\Local\Temp\ipykernel_14104\2714125096.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result = df.groupby("category_id").sum().sort_values("comment_count",ascending=False)["comment_count"]
# category_id
# 10    293013140
# 24    116897440
# 22     18713149
# 23     16718816
# 1      15590011
# 17     10056226
# 25      9386604
# 29      7672790
# 26      7356296
# 20      6166994
# 28      4029065
# 27      1636903
# 15      1404698
# 2        505085
# 19       118177
# 43        80957
# Name: comment_count, dtype: int64

# %%
#12-
result = df["category_id"].value_counts()
result
# Out:
# 10    13754
# 24     9124
# 22     2926
# 1      2577
# 26     1928
# 17     1907
# 23     1828
# 20     1788
# 25     1225
# 15      534
# 28      518
# 27      457
# 2       144
# 19       96
# 29       90
# 43       20
# Name: category_id, dtype: int64

# %%
#13-
df["title_len"] = df["title"].apply(len)

result = df
result
# Out:
#           video_id                                              title  \
# 0      Jw1Y-zhQURU      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1      3s1rvMFUweQ          Taylor Swift: …Ready for It? (Live) - SNL
# 2      n1WpP7iowLc         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      PUTEiSjKwJU  Goals from Salford City vs Class of 92 and Fri...
# 4      rHwDegptbI4  Dashcam captures truck's near miss with child ...
# ...            ...                                                ...
# 38911  l884wKofd54  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  IP8k2xkhOdI  Jacob Sartorius - Up With It (Official Music V...
# 38913  Il-an3K9pjg                 Anne-Marie - 2002 [Official Video]
# 38914  -DRsfNObKIQ  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  4YFo4bdMO8Q  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                     channel_title  category_id              publish_time  \
# ...

# %%
#14-
df["tag_count"] = df["tags"].apply(lambda x: len(x.split("|")))
df
# Out:
#           video_id                                              title  \
# 0      Jw1Y-zhQURU      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1      3s1rvMFUweQ          Taylor Swift: …Ready for It? (Live) - SNL
# 2      n1WpP7iowLc         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      PUTEiSjKwJU  Goals from Salford City vs Class of 92 and Fri...
# 4      rHwDegptbI4  Dashcam captures truck's near miss with child ...
# ...            ...                                                ...
# 38911  l884wKofd54  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  IP8k2xkhOdI  Jacob Sartorius - Up With It (Official Music V...
# 38913  Il-an3K9pjg                 Anne-Marie - 2002 [Official Video]
# 38914  -DRsfNObKIQ  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  4YFo4bdMO8Q  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                     channel_title  category_id              publish_time  \
# ...

# %%
#15-
likeslist = list(df["likes"])
dislikeslist = list(df["dislikes"])

def likedislikeoranhesapla(dataset):
    likeslist = list(dataset["likes"])
    dislikeslist = list(dataset["dislikes"])
    
    liste = list(zip(likeslist,dislikeslist)) # tuple listesi şekilnde gelecek (1020,230) gibi
    
    oranlistesi = []
    
    for like,dislike in liste:
        if (like + dislike) == 0:
            oranlistesi.append(0)
        else:
            oranlistesi.append(like/(like + dislike))
        
    
    return oranlistesi
    





df["beğeni_orani"] = likedislikeoranhesapla(df)

print(df.sort_values("beğeni_orani",ascending = False)[["title","likes","dislikes","beğeni_orani"]])
# Out:
#                                                    title  likes  dislikes  \
# 36631         Kris Wu – Like That (Official Music Video)  57544         0
# 7088      HIGHLIGHTS: MK Dons U18s 1-0 Cardiff City U18s     30         0
# 5361         QUIZ : Name the Trail : A Christmas Cracker      2         0
# 12082    Lima Sopoaga Tribute🔥🔥||The Unsung Hero||💯 2017     50         0
# 5338   Bohemian Rhapsody (2018) - Scene Bohemian Rhap...     71         0
# ...                                                  ...    ...       ...
# 21547                                    To Our Daughter      0         0
# 22661                      【公式】「劇場版ポケットモンスター みんなの物語」予告編1      0         0
# 24920                    映画『BLEACH』特報【HD】2018年7月20日（金）公開      0         0
# 14864                             Altwork 1 Minute Video      0         0
# 4465                      The New Snapchat in 60 Seconds      0         0
#
#        beğeni_orani
# 36631           1.0
# 7088            1.0
# ...
